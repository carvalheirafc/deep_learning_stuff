# %% [markdown]
# <a href="https://colab.research.google.com/github/carvalheirafc/deep_learning_stuff/blob/master/img_process/task4/question2ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
import numpy

# %%
img_file = 'Lista4_Img1.jpg'
img = cv2.imread(img_file)

plt.imshow(img)

# %% [markdown]
# ## Standard Kernels and Filters

# %%
blur = cv2.blur(img,(5,5))
g_blur = cv2.GaussianBlur(img,(5,5),0)
median = cv2.medianBlur(img,5)
bilateral = cv2.bilateralFilter(img,9,75,75)

# %%
f = plt.figure(figsize=(25,25))
ax_1 = f.add_subplot(141)
ax_1 = plt.imshow(blur)
ax_1 = plt.title('Blur')

ax_2 = f.add_subplot(142)
ax_2 = plt.imshow(g_blur)
ax_2 = plt.title('Gaussian Blur')

ax_3 = f.add_subplot(143)
ax_3 = plt.imshow(median)
ax_3 = plt.title('Median Blur')

ax_4 = f.add_subplot(144)
ax_4 = plt.imshow(bilateral)
ax_4 = plt.title('Bilateral')

# %%
p_img = cv2.blur(img,(5,5))
p_img = cv2.GaussianBlur(img,(5,5),0)
p_img = cv2.medianBlur(img,5)
p_img = cv2.bilateralFilter(img,9,75,75)

# %%
f = plt.figure(figsize=(10, 10))
ax = f.add_subplot(111)
ax = plt.imshow(p_img)
