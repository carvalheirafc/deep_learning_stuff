# %% [markdown]
# <a href="https://colab.research.google.com/github/carvalheirafc/deep_learning_stuff/blob/master/img_process/task4/fourier_transformation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas
import numpy
import matplotlib.pyplot as plt

# %%
file_path = 'Lista4_Dados1.xlsx'

df = pandas.read_excel(file_path)
df.head()
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3
# 0         NaN         NaN           X           Y
# 1         NaN         NaN           0           0
# 2         NaN         NaN      0.1000     -0.3757
# 3         NaN         NaN      0.2000      -18554
# 4         NaN         NaN      0.3000      -19633

# %%
X = df['Unnamed: 2'].iloc[2:].astype(float)
Y = df['Unnamed: 3'].iloc[2:].astype(float)

# %%
fig, ax = plt.subplots(figsize=(15, 5))
ax = plt.plot(X, Y)
